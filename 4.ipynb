# %%
import pandas as pd
df = pd.read_csv("./data/winemag-data-130k-v2.csv", index_col=0)

# %%
df.points.sort_values().unique()
# Out:
# array([ 80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#         93,  94,  95,  96,  97,  98,  99, 100])

# %%
df.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
df.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
df.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
df.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Armenia   Armenia             Armenia
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# Armenia   Armenia           Deep salmon in color, this wine offers a bouqu...
# Australia Australia Other   Writes the book on how to make a wine filled w...
# ...

# %%
df.groupby(['country']).price.agg([len, min, max])
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4472.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2165.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
df.reset_index()
# Out:
#          index   country                                        description  \
# 0            0     Italy  Aromas include tropical fruit, broom, brimston...
# 1            1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2        US  Tart and snappy, the flavors of lime flesh and...
# 3            3        US  Pineapple rind, lemon pith and orange blossom ...
# 4            4        US  Much like the regular bottling from 2012, this...
# ...        ...       ...                                                ...
# 129966  129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  129967        US  Citation is given as much as a decade of bottl...
# 129968  129968    France  Well-drained gravel soil gives this wine its c...
# 129969  129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970  129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
df.sort_values(by=['price'], ascending=False)
# Out:
#          country                                        description  \
# 80290     France  This ripe wine shows plenty of blackberry frui...
# 15840     France  The wine is a velvet glove in an iron fist. Th...
# 98380     France  A superb wine from a great year, this is power...
# 120391        US  The nose on this single-vineyard wine from a s...
# 113564    France  A wonderfully complete wine, with all the elem...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points   price    province  \
# 80290                            NaN      88  3300.0    Bordeaux
# ...

# %%
df1 = df.sort_values(by=['points', 'price'])
df1
# Out:
#           country                                        description  \
# 23437   Argentina  Candied plum and red berry aromas smell like r...
# 125826  Argentina  While this smells floral and candied, the pala...
# 34501       Chile  Neutral aromas, sour apple and citrus flavors,...
# 81390       Spain  Very light, even thin, this white lacks the st...
# 99996       Chile  The nose is sulphuric and a bit barnyardy, whi...
# ...           ...                                                ...
# 89729      France  This new release from a great vintage for Char...
# 114972   Portugal  A powerful and ripe wine, strongly influenced ...
# 122935     France  Full of ripe fruit, opulent and concentrated, ...
# 111753     France  Almost black in color, this stunning wine is g...
# 111755     France  This is the finest Cheval Blanc for many years...
#
#                            designation  points   price          province  \
# ...

# %%
df1.reset_index(drop=True)
# Out:
#           country                                        description  \
# 0       Argentina  Candied plum and red berry aromas smell like r...
# 1       Argentina  While this smells floral and candied, the pala...
# 2           Chile  Neutral aromas, sour apple and citrus flavors,...
# 3           Spain  Very light, even thin, this white lacks the st...
# 4           Chile  The nose is sulphuric and a bit barnyardy, whi...
# ...           ...                                                ...
# 129966     France  This new release from a great vintage for Char...
# 129967   Portugal  A powerful and ripe wine, strongly influenced ...
# 129968     France  Full of ripe fruit, opulent and concentrated, ...
# 129969     France  Almost black in color, this stunning wine is g...
# 129970     France  This is the finest Cheval Blanc for many years...
#
#                            designation  points   price          province  \
# ...
