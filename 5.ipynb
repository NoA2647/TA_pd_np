# %%
import pandas as pd
df = pd.read_csv('./data/winemag-data-130k-v2.csv', index_col=0)

# %%
df.price.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df[pd.isnull(df.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
df.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129966              Unknown
# 129967         Oregon Other
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
df.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
df.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  score  price  \
# 0                                 Vulkà Bianco     87    NaN
# ...

# %%
df.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# 2                  US  Tart and snappy, the flavors of lime flesh and...
# 3                  US  Pineapple rind, lemon pith and orange blossom ...
# 4                  US  Much like the regular bottling from 2012, this...
# ...               ...                                                ...
# 129966        Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967             US  Citation is given as much as a decade of bottl...
# 129968         France  Well-drained gravel soil gives this wine its c...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                         designation  points  price  \
# ...

# %%
df.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                             designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
canadian_youtube = pd.read_csv("./data/CAvideos.csv")
united_youtube = pd.read_csv("./data/USvideos.csv")

print(canadian_youtube.shape)
print(united_youtube.shape)

pd.concat([canadian_youtube, united_youtube]) # axis=0
# Out:
# (40881, 16)
# (40949, 16)
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
left = canadian_youtube.set_index(['trending_date']) # test ['title', 'trending_date']
right = united_youtube.set_index(['trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_US')
# Out:
#               video_id_CAN                                          title_CAN  \
# trending_date
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 17.01.12       6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# ...                    ...                                                ...
# 18.31.05       zNZJNlx4P80    WE TRIED TO MAKE TASTY'S GIANT MACARON (VERSUS)
# 18.31.05       zNZJNlx4P80    WE TRIED TO MAKE TASTY'S GIANT MACARON (VERSUS)
# 18.31.05       zNZJNlx4P80    WE TRIED TO MAKE TASTY'S GIANT MACARON (VERSUS)
# 18.31.05       zNZJNlx4P80    WE TRIED TO MAKE TASTY'S GIANT MACARON (VERSUS)
# 18.31.05       zNZJNlx4P80    WE TRIED TO MAKE TASTY'S GIANT MACARON (VERSUS)
#
# ...
